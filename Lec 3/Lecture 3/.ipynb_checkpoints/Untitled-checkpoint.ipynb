# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
dataTrain = pd.read_csv("dataTrain.csv")
dataTest = pd.read_csv("dataTest.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dataTrain
# Out:
#     Crop Name        Area Name  Area of Land in acres  \
# 0         Aus        Bakergonj                 470150
# 1         Aus            Bogra                 286080
# 2         Aus       Chittagong                 264775
# 3         Aus  Chittagong H.T.                 128710
# 4         Aus          Comilla                 566325
# 5         Aus            Dhaka                 499125
# 6         Aus         Dinajpur                 484460
# 7         Aus         Faridpur                 577015
# 8         Aus          Jessore                 636155
# 9         Aus           Khulna                 119700
# 10        Aus      Kishoregonj                 218880
# 11        Aus          Kushtia                 359405
# 12        Aus       Mymensingh                1089970
# 13        Aus         Noakhali                 478290
# 14        Aus            Pabna                 414815
# 15        Aus       Patuakhali                 126740
# 16        Aus         Rajshahi                 474080
# 17        Aus          Rangpur                 906800
# 18        Aus           Sylhet                 360260
# 19        Aus          Tangail                      0
# 20        Aus        Bakergonj                 508750
# 21        Aus            Bogra                 228600
# 22        Aus       Chittagong                 217790
# 23        Aus  Chittagong H.T.                 121610
# 24        Aus          Comilla                 564220
# 25        Aus            Dhaka                 400750
# 26        Aus         Dinajpur                 489920
# 27        Aus         Faridpur                 479420
# 28        Aus          Jessore                 637010
# 29        Aus           Khulna                  83640
# ..        ...              ...                    ...
# 168       Aus          Jessore                 637130
# 169       Aus           Khulna                 109320
# 170       Aus      Kishoregonj                 233025
# 171       Aus          Kushtia                 351520
# 172       Aus       Mymensingh                 714730
# 173       Aus         Noakhali                 312290
# 174       Aus            Pabna                 367750
# 175       Aus       Patuakhali                 139115
# 176       Aus         Rajshahi                 477060
# 177       Aus          Rangpur                 976000
# 178       Aus           Sylhet                 350000
# 179       Aus          Tangail                 289310
# 180       Aus        Bakergonj                 457465
# 181       Aus            Bogra                 292100
# 182       Aus       Chittagong                 217115
# 183       Aus  Chittagong H.T.                  90675
# 184       Aus          Comilla                 464690
# 185       Aus            Dhaka                 380420
# 186       Aus         Dinajpur                 497925
# 187       Aus         Faridpur                 551100
# 188       Aus          Jessore                 619325
# 189       Aus           Khulna                 110175
# 190       Aus      Kishoregonj                 205575
# 191       Aus          Kushtia                 370125
# 192       Aus       Mymensingh                 722490
# 193       Aus         Noakhali                 329880
# 194       Aus            Pabna                 387125
# 195       Aus       Patuakhali                 140565
# 196       Aus         Rajshahi                      0
# 197       Aus          Rangpur                 996550
#
#      Amount of Production in Tons  Year
# 0                          181155  1969
# 1                           95240  1969
# 2                          121470  1969
# 3                           60160  1969
# 4                          224045  1969
# 5                          185035  1969
# 6                          187185  1969
# 7                          164925  1969
# 8                          214345  1969
# 9                           49115  1969
# 10                          54375  1969
# 11                          97455  1969
# 12                         325685  1969
# 13                         154690  1969
# 14                         145150  1969
# 15                          39200  1969
# 16                         173860  1969
# 17                         324985  1969
# 18                         164960  1969
# 19                              0  1969
# 20                         185765  1970
# 21                          81120  1970
# 22                         100405  1970
# 23                          44360  1970
# 24                         213480  1970
# 25                         145300  1970
# 26                         189150  1970
# 27                         142475  1970
# 28                         226515  1970
# 29                          33645  1970
# ..                            ...   ...
# 168                        273115  1977
# 169                         46255  1977
# 170                        102005  1977
# 171                        135620  1977
# 172                        304055  1977
# 173                        166645  1977
# 174                        113160  1977
# 175                         47395  1977
# 176                        181435  1977
# 177                        329220  1977
# 178                        174110  1977
# 179                        114690  1977
# 180                        176125  1978
# 181                        120680  1978
# 182                        154065  1978
# 183                         38480  1978
# 184                        237135  1978
# 185                        160060  1978
# 186                        201895  1978
# 187                        150380  1978
# 188                        261270  1978
# 189                         50365  1978
# 190                         83750  1978
# 191                        151070  1978
# 192                        328815  1978
# 193                        170765  1978
# 194                        129340  1978
# 195                         49670  1978
# 196                        171035  1978
# 197                        349205  1978
#
# [198 rows x 5 columns]

# %%
dataTest
# Out:
#    Crop Name     Area Name  Area of Land in acres  \
# 0        Aus    Bandarban                   30180
# 1        Aus      Barisal                  357900
# 2        Aus        Bogra                   19730
# 3        Aus   Chittagong                  106640
# 4        Aus      Comilla                  266460
# 5        Aus        Dhaka                  117280
# 6        Aus     Dinajpur                   42040
# 7        Aus     Faridpur                  317710
# 8        Aus     Jamalpur                   65140
# 9        Aus      Jessore                  220870
# 10       Aus  Khagrachari                    3700
# 11       Aus       Khulna                   31390
# 12       Aus  Kishoregonj                  139750
# 13       Aus      Kushtia                  173320
# 14       Aus   Mymensingh                  186180
# 15       Aus     Noakhali                  219240
# 16       Aus        Pabna                   60460
# 17       Aus   Patuakhali                  253490
# 18       Aus     Rajshahi                  161010
# 19       Aus    Rangamati                   11430
# 20       Aus      Rangpur                   31700
# 21       Aus       Sylhet                  396940
# 22       Aus      Tangail                   62210
# 23       Aus    Bandarban                   23400
# 24       Aus      Barisal                  386160
# 25       Aus        Bogra                   18060
# 26       Aus   Chittagong                  113580
# 27       Aus      Comilla                  271060
# 28       Aus        Dhaka                  114850
# 29       Aus     Dinajpur                   28770
# ..       ...           ...                    ...
# 69       Aus    Bandarban                   25320
# 70       Aus      Barisal                  383740
# 71       Aus        Bogra                   17890
# 72       Aus   Chittagong                  126820
# 73       Aus      Comilla                  229040
# 74       Aus        Dhaka                  107500
# 75       Aus     Dinajpur                   27130
# 76       Aus     Faridpur                  327240
# 77       Aus     Jamalpur                   43050
# 78       Aus      Jessore                  165240
# 79       Aus  Khagrachari                    5870
# 80       Aus       Khulna                   29550
# 81       Aus  Kishoregonj                   89470
# 82       Aus      Kushtia                  130630
# 83       Aus   Mymensingh                  161460
# 84       Aus     Noakhali                  213550
# 85       Aus        Pabna                   71570
# 86       Aus   Patuakhali                  252060
# 87       Aus     Rajshahi                  185920
# 88       Aus    Rangamati                   11850
# 89       Aus      Rangpur                   20450
# 90       Aus       Sylhet                  291360
# 91       Aus      Tangail                   54990
# 92       Aus    Bandarban                   24560
# 93       Aus      Barisal                  380260
# 94       Aus        Bogra                   17120
# 95       Aus   Chittagong                  112250
# 96       Aus      Comilla                  207260
# 97       Aus        Dhaka                   57420
# 98       Aus     Dinajpur                   24980
#
#     Amount of Production in Tons  Year
# 0                          17870  2000
# 1                         185360  2000
# 2                          13450  2000
# 3                          86960  2000
# 4                         197330  2000
# 5                          44170  2000
# 6                          30840  2000
# 7                         132840  2000
# 8                          32470  2000
# 9                         152920  2000
# 10                          2830  2000
# 11                         20670  2000
# 12                         95560  2000
# 13                        106020  2000
# 14                        116570  2000
# 15                        122050  2000
# 16                         22870  2000
# 17                        146690  2000
# 18                         99140  2000
# 19                          7360  2000
# 20                         13690  2000
# 21                        245440  2000
# 22                         22500  2000
# 23                         14020  2001
# 24                        210670  2001
# 25                         12120  2001
# 26                         90730  2001
# 27                        199690  2001
# 28                         48540  2001
# 29                         15510  2001
# ..                           ...   ...
# 69                         15170  2003
# 70                        201220  2003
# 71                         12060  2003
# 72                        108360  2003
# 73                        165300  2003
# 74                         46340  2003
# 75                         23780  2003
# 76                        142180  2003
# 77                         20070  2003
# 78                        114240  2003
# 79                          6640  2003
# 80                         21210  2003
# 81                         64380  2003
# 82                         74560  2003
# 83                        112890  2003
# 84                        123190  2003
# 85                         32280  2003
# 86                        157160  2003
# 87                        125120  2003
# 88                          7860  2003
# 89                         12040  2003
# 90                        213460  2003
# 91                         32330  2003
# 92                         13390  2004
# 93                        192580  2004
# 94                         11850  2004
# 95                        100830  2004
# 96                        140460  2004
# 97                         22780  2004
# 98                         19480  2004
#
# [99 rows x 5 columns]

# %%
x_train = dataTrain[['Area of Land in acres','Year']]#.reshape(-1,2)
#x_train = x_train.values
#x_train = x_train.reshape(-1,2)
y_train = dataTrain['Amount of Production in Tons']
#y_train = y_train.values
x_test = dataTest[['Area of Land in acres','Year']]#.reshape(-1,2)
y_test = dataTest['Amount of Production in Tons']

# %%
#x_train, x_test, y_train, y_test = cross_validation.train_test_split(x, y, test_size=0.3)

clf = LinearRegression()

clf.fit(x_train, y_train)

accuracy= clf.score(x_test, y_test)
print("The accuracy of the network is:", accuracy)
print("Prediction for the Test set is:")
print( clf.predict(x_test) )
print("Lets Compare it to the original target test set:")
print(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-a5fee1fb5b4c> in <module>()
#       1 #x_train, x_test, y_train, y_test = cross_validation.train_test_split(x, y, test_size=0.3)
#       2
# ----> 3 clf = LinearRegression()
#       4
#       5 clf.fit(x_train, y_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
#print (model.predict(x_test))
#print(clf.predict(x_test))
print(accuracy)
#plt.plot(x_train,y_train,"*") 
plt.plot(x_test,y_test,"+") 
plt.show()
# Out:
# [112174.24829849 220522.94534513 108719.33592165 137452.96603371
#  190291.63551374 140970.69499922 116095.32588598 207235.58377335
#  123732.50061373 175218.96036923 103419.59951967 112574.29078423
#  148399.58314348 159498.28252056 163749.97373263 174680.06016117
#  122185.22885071 186003.57680296 155428.42880201 105975.24283766
#  112676.78100785 233430.10124865 122763.80269372 113317.31990893
#  233250.71836077 111551.84315368 143132.05657335 195197.09017186
#  143551.93587657 115092.71507291 216653.91440696 122759.64502687
#  162043.1558992  107300.15194161 116187.04617026 139574.65397289
#  156062.35543059 161527.39864486 177982.0387401  126363.33353477
#  187632.65044152 153404.22188898 109254.07846286 113776.87284709
#  212550.99932595 125030.96062772 117558.24118165 232935.78388682
#  114896.8015038  148040.81736773 191261.93650878 144800.80384686
#  119532.00452038 213793.25502376 124425.08616413 166241.09740074
#  110879.84596518 118791.43000133 140340.82605131 156054.89162749
#  164746.72381764 183287.53588397 132280.4658841  192729.86100191
#  169805.11227368 113157.77383852 118001.26343859 221208.91862304
#  127532.85423517 120721.36203826 239219.89735943 118264.90280764
#  154278.6449329  188073.96963725 147891.18970606 121319.77269874
#  220540.22757079 126583.14160202 166980.82038918 114290.92704022
#  122119.85767022 141930.22605492 155538.28284255 165731.10088828
#  182952.76459254 136012.24217498 195684.69527503 173817.91014545
#  116267.99651519 119111.27368656 208677.81072094 130530.66827948
#  123854.72766865 241453.99393097 121394.96230179 152846.23640788
#  184257.83687901 134718.69137228 123993.58539097]
